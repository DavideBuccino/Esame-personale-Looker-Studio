# %%
import pandas as pd

# Dati dei cantanti solisti (COMPLETO, 51 artisti)
solisti = [
    {"Artista": "Nilla Pizzi", "Data di nascita": "16 aprile 1919", "Anno di nascita": 1919, "Luogo di nascita": "Sant’Agata Bolognese (BO)"},
    {"Artista": "Carla Boni", "Data di nascita": "26 giugno 1925", "Anno di nascita": 1925, "Luogo di nascita": "Bologna"},
    {"Artista": "Gino Latilla", "Data di nascita": "25 maggio 1924", "Anno di nascita": 1924, "Luogo di nascita": "Bari"},
    {"Artista": "Claudio Villa", "Data di nascita": "1° gennaio 1926", "Anno di nascita": 1926, "Luogo di nascita": "Roma"},
    {"Artista": "Domenico Modugno", "Data di nascita": "9 gennaio 1928", "Anno di nascita": 1928, "Luogo di nascita": "Polignano a Mare (BA)"},
    {"Artista": "Franca Raimondi", "Data di nascita": "8 luglio 1932", "Anno di nascita": 1932, "Luogo di nascita": "Napoli"},
    {"Artista": "Tony Renis", "Data di nascita": "13 maggio 1938", "Anno di nascita": 1938, "Luogo di nascita": "Milano"},
    {"Artista": "Gigliola Cinquetti", "Data di nascita": "20 dicembre 1947", "Anno di nascita": 1947, "Luogo di nascita": "Verona"},
    {"Artista": "Bobby Solo", "Data di nascita": "18 marzo 1945", "Anno di nascita": 1945, "Luogo di nascita": "Roma"},  # Aggiunto
    {"Artista": "Nicola Di Bari", "Data di nascita": "29 settembre 1940", "Anno di nascita": 1940, "Luogo di nascita": "Zapponeta (FG)"},
    {"Artista": "Peppino di Capri", "Data di nascita": "27 luglio 1939", "Anno di nascita": 1939, "Luogo di nascita": "Capri (NA)"},
    {"Artista": "Gilda (Miranda Bonansea)", "Data di nascita": "28 maggio 1951", "Anno di nascita": 1951, "Luogo di nascita": "Torino"},
    {"Artista": "Mino Vergnaghi", "Data di nascita": "6 dicembre 1951", "Anno di nascita": 1951, "Luogo di nascita": "Milano"},
    {"Artista": "Sergio Endrigo", "Data di nascita": "15 giugno 1933", "Anno di nascita": 1933, "Luogo di nascita": "Pola (allora Italia, oggi Croazia)"},
    {"Artista": "Al Bano (Albano Carrisi)", "Data di nascita": "20 maggio 1943", "Anno di nascita": 1943, "Luogo di nascita": "Cellino San Marco (BR)"},
    {"Artista": "Tony Dallara", "Data di nascita": "30 giugno 1936", "Anno di nascita": 1936, "Luogo di nascita": "Campobasso"},
    {"Artista": "Betty Curtis (Roberta Corti)", "Data di nascita": "21 marzo 1936", "Anno di nascita": 1936, "Luogo di nascita": "Busto Arsizio (VA)"},
    {"Artista": "Iva Zanicchi", "Data di nascita": "18 gennaio 1940", "Anno di nascita": 1940, "Luogo di nascita": "Ligonchio (RE)"},
    {"Artista": "Adriano Celentano", "Data di nascita": "6 gennaio 1938", "Anno di nascita": 1938, "Luogo di nascita": "Milano"},
    {"Artista": "Toto Cutugno", "Data di nascita": "7 luglio 1943", "Anno di nascita": 1943, "Luogo di nascita": "Fosdinovo (MS)"},
    {"Artista": "Nada (Nada Malanima)", "Data di nascita": "17 dicembre 1953", "Anno di nascita": 1953, "Luogo di nascita": "Montecchio (LU)"},
    {"Artista": "Alice (Carla Bissi)", "Data di nascita": "26 settembre 1954", "Anno di nascita": 1954, "Luogo di nascita": "Forlì"},
    {"Artista": "Riccardo Fogli", "Data di nascita": "21 ottobre 1947", "Anno di nascita": 1947, "Luogo di nascita": "Pontedera (PI)"},
    {"Artista": "Eros Ramazzotti", "Data di nascita": "28 ottobre 1963", "Anno di nascita": 1963, "Luogo di nascita": "Roma"},
    {"Artista": "Gianni Morandi", "Data di nascita": "11 dicembre 1944", "Anno di nascita": 1944, "Luogo di nascita": "Monghidoro (BO)"},
    {"Artista": "Massimo Ranieri (Giovanni Calone)", "Data di nascita": "3 maggio 1951", "Anno di nascita": 1951, "Luogo di nascita": "Napoli"},
    {"Artista": "Anna Oxa (Anna Hoxha)", "Data di nascita": "28 aprile 1961", "Anno di nascita": 1961, "Luogo di nascita": "Bari"},
    {"Artista": "Riccardo Cocciante", "Data di nascita": "20 febbraio 1946", "Anno di nascita": 1946, "Luogo di nascita": "Saigon (Vietnam)"},
    {"Artista": "Luca Barbarossa", "Data di nascita": "26 aprile 1961", "Anno di nascita": 1961, "Luogo di nascita": "Roma"},
    {"Artista": "Enrico Ruggeri", "Data di nascita": "5 giugno 1957", "Anno di nascita": 1957, "Luogo di nascita": "Milano"},
    {"Artista": "Aleandro Baldi", "Data di nascita": "12 giugno 1959", "Anno di nascita": 1959, "Luogo di nascita": "Terranuova Bracciolini (AR)"},
    {"Artista": "Giorgia (Giorgia Todrani)", "Data di nascita": "26 aprile 1971", "Anno di nascita": 1971, "Luogo di nascita": "Roma"},
    {"Artista": "Ron (Rosalino Cellamare)", "Data di nascita": "13 agosto 1953", "Anno di nascita": 1953, "Luogo di nascita": "Milano"},
    {"Artista": "Annalisa Minetti", "Data di nascita": "20 gennaio 1973", "Anno di nascita": 1973, "Luogo di nascita": "Rozzano (MI)"},
    {"Artista": "Elisa (Elisa Toffoli)", "Data di nascita": "19 dicembre 1977", "Anno di nascita": 1977, "Luogo di nascita": "Monfalcone (GO)"},
    {"Artista": "Alexia (Alessia Aquilani)", "Data di nascita": "13 maggio 1967", "Anno di nascita": 1967, "Luogo di nascita": "La Spezia"},
    {"Artista": "Marco Masini", "Data di nascita": "18 settembre 1964", "Anno di nascita": 1964, "Luogo di nascita": "Firenze"},
    {"Artista": "Francesco Renga", "Data di nascita": "2 marzo 1968", "Anno di nascita": 1968, "Luogo di nascita": "Saronno (VA)"},
    {"Artista": "Povia (Giuseppe Povia)", "Data di nascita": "19 novembre 1972", "Anno di nascita": 1972, "Luogo di nascita": "Milano"},
    {"Artista": "Simone Cristicchi", "Data di nascita": "5 febbraio 1977", "Anno di nascita": 1977, "Luogo di nascita": "Roma"},
    {"Artista": "Giò Di Tonno (Giovanni Di Tonno)", "Data di nascita": "9 giugno 1967", "Anno di nascita": 1967, "Luogo di nascita": "Bari"},
    {"Artista": "Marco Carta", "Data di nascita": "21 maggio 1985", "Anno di nascita": 1985, "Luogo di nascita": "Cagliari"},
    {"Artista": "Valerio Scanu", "Data di nascita": "2 aprile 1990", "Anno di nascita": 1990, "Luogo di nascita": "Sassari"},
    {"Artista": "Roberto Vecchioni", "Data di nascita": "25 giugno 1943", "Anno di nascita": 1943, "Luogo di nascita": "Milano"},
    {"Artista": "Emma Marrone", "Data di nascita": "25 maggio 1984", "Anno di nascita": 1984, "Luogo di nascita": "Firenze"},
    {"Artista": "Marco Mengoni", "Data di nascita": "25 dicembre 1988", "Anno di nascita": 1988, "Luogo di nascita": "Ronciglione (VT)"},
    {"Artista": "Arisa (Rosalba Pippa)", "Data di nascita": "20 agosto 1982", "Anno di nascita": 1982, "Luogo di nascita": "Pistoia"},
    {"Artista": "Francesco Gabbani", "Data di nascita": "9 settembre 1982", "Anno di nascita": 1982, "Luogo di nascita": "Carrara"},
    {"Artista": "Ermal Meta", "Data di nascita": "20 aprile 1981", "Anno di nascita": 1981, "Luogo di nascita": "Fier (Albania)"},
    {"Artista": "Mahmood (Alessandro Mahmoud)", "Data di nascita": "12 settembre 1992", "Anno di nascita": 1992, "Luogo di nascita": "Milano"},
    {"Artista": "Diodato (Antonio Diodato)", "Data di nascita": "30 agosto 1981", "Anno di nascita": 1981, "Luogo di nascita": "Aosta"}
]

# Dati dei gruppi (9 gruppi con media anni)
gruppi = [
    {"Artista": "Ricchi e Poveri", "Anno di nascita": (1947 + 1942 + 1949 + 1946) / 4, "Membri": "Angela Brambati, Franco Gatti, Marina Occhiena, Angelo Sotgiu"},
    {"Artista": "Homo Sapiens", "Anno di nascita": (1948 + 1947) / 2, "Membri": "Claudio Pascoli, Maurizio Vandelli"},
    {"Artista": "Matia Bazar", "Anno di nascita": (1952 + 1951 + 1952 + 1952) / 4, "Membri": "Aldo Stellita, Carlo Marrale, Piercarlo Tanzi, Antonella Ruggiero"},
    {"Artista": "Pooh", "Anno di nascita": (1944 + 1951 + 1954 + 1948) / 4, "Membri": "Robbie Facchinetti, Dodi Battaglia, Red Canzian, Stefano D’Orazio"},
    {"Artista": "Jalisse", "Anno di nascita": (1969 + 1968) / 2, "Membri": "Alessandra Drusian, Fabio Ricci"},
    {"Artista": "Piccola Orchestra Avion Travel", "Anno di nascita": (1954 + 1955 + 1956) / 3, "Membri": "Peppe Servillo, Fausto Mesolella, Mimì Ciaramella"},
    {"Artista": "Il Volo", "Anno di nascita": (1993 + 1994 + 1995) / 3, "Membri": "Piero Barone, Ignazio Boschetto, Gianluca Ginoble"},
    {"Artista": "Stadio", "Anno di nascita": (1957 + 1958 + 1959) / 3, "Membri": "Gaetano Curreri, Giovanni Pezzoli, Andrea Fornili"},
    {"Artista": "Måneskin", "Anno di nascita": (1999 + 2000 + 2001 + 2000) / 4, "Membri": "Damiano David, Victoria De Angelis, Thomas Raggi, Ethan Torchio"}
]

# Creazione dei DataFrame
df_solisti = pd.DataFrame(solisti)
df_gruppi = pd.DataFrame(gruppi)

# Unione e salvataggio
df_finale = pd.concat([
    df_solisti[["Artista", "Data di nascita", "Anno di nascita", "Luogo di nascita"]],
    df_gruppi[["Artista", "Anno di nascita", "Membri"]].assign(**{"Data di nascita": "", "Luogo di nascita": ""})
], ignore_index=True)

df_finale["Anno di nascita"] = df_finale["Anno di nascita"].round().astype(int)
df_finale.to_excel("Anagrafica_Vincitori_Sanremo.xlsx", index=False)

print("File Excel generato con successo!")
# Out:
# File Excel generato con successo!

# %%
print(df_finale[df_finale["Artista"] == "Bobby Solo"])
# Out:
#       Artista Data di nascita  Anno di nascita Luogo di nascita Membri
# 8  Bobby Solo   18 marzo 1945             1945             Roma    NaN

# %%
df_finale
# Out:
#                               Artista    Data di nascita  Anno di nascita  \
# 0                         Nilla Pizzi     16 aprile 1919             1919
# 1                          Carla Boni     26 giugno 1925             1925
# 2                        Gino Latilla     25 maggio 1924             1924
# 3                       Claudio Villa    1° gennaio 1926             1926
# 4                    Domenico Modugno     9 gennaio 1928             1928
# 5                     Franca Raimondi      8 luglio 1932             1932
# 6                          Tony Renis     13 maggio 1938             1938
# 7                  Gigliola Cinquetti   20 dicembre 1947             1947
# 8                          Bobby Solo      18 marzo 1945             1945
# 9                      Nicola Di Bari  29 settembre 1940             1940
# 10                   Peppino di Capri     27 luglio 1939             1939
# 11           Gilda (Miranda Bonansea)     28 maggio 1951             1951
# ...
